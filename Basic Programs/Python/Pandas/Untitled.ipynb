# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name":["alpha", "beta", "gamma", "delta"],
    "marks":[24, 12, 6, 43],
    "city":["Pune", "Pimpri", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks       city
# 0  alpha     24       Pune
# 1   beta     12     Pimpri
# 2  gamma      6     Mumbai
# 3  delta     43  Bangalore

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_without_index.csv', index = False)

# %%
df.head(2)
# Out:
#     name  marks    city
# 0  alpha     24    Pune
# 1   beta     12  Pimpri

# %%
df.tail(2)
# Out:
#     name  marks       city
# 2  gamma      6     Mumbai
# 3  delta     43  Bangalore

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   21.250000
# std    16.317169
# min     6.000000
# 25%    10.500000
# 50%    18.000000
# 75%    28.750000
# max    43.000000

# %%
pd.read_csv('friends.csv')
# Out:
#    Unnamed: 0   name  marks       city
# 0           0  alpha     24       Pune
# 1           1   beta     12     Pimpri
# 2           2  gamma      6     Mumbai
# 3           3  delta     43  Bangalore

# %%
friends = pd.read_csv('friends.csv')

# %%
friends
# Out:
#    Unnamed: 0   name  marks       city
# 0           0  alpha     24       Pune
# 1           1   beta     12     Pimpri
# 2           2  gamma      6     Mumbai
# 3           3  delta     43  Bangalore

# %%
friends['marks']
# Out:
# 0    24
# 1    12
# 2     6
# 3    43
# Name: marks, dtype: int64

# %%
friends['marks'][0] = 240
# Out:
# <ipython-input-16-baa0ca4bae8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   friends['marks'][0] = 240

# %%
friends
# Out:
#    Unnamed: 0   name  marks       city
# 0           0  alpha    240       Pune
# 1           1   beta     12     Pimpri
# 2           2  gamma      6     Mumbai
# 3           3  delta     43  Bangalore

# %%
friends.to_csv('friends.csv')

# %%
friends.index = ["First", "Second", "Third", "Fourth"]

# %%
friends
# Out:
#         Unnamed: 0   name  marks       city
# First            0  alpha    240       Pune
# Second           1   beta     12     Pimpri
# Third            2  gamma      6     Mumbai
# Fourth           3  delta     43  Bangalore

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0    <built-in method rand of numpy.random.mtrand.R...
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334, 5), index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.495462  0.862850  0.341169  0.201986  0.768530
# 1  0.144299  0.061437  0.126066  0.705308  0.810076
# 2  0.534083  0.332580  0.643512  0.552869  0.787630
# 3  0.978991  0.503777  0.756358  0.831947  0.367766
# 4  0.983951  0.579067  0.858073  0.202628  0.905762

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.495462  0.862850  0.341169  0.201986  0.768530
# 1    0.144299  0.061437  0.126066  0.705308  0.810076
# 2    0.534083  0.332580  0.643512  0.552869  0.787630
# 3    0.978991  0.503777  0.756358  0.831947  0.367766
# 4    0.983951  0.579067  0.858073  0.202628  0.905762
# ..        ...       ...       ...       ...       ...
# 329  0.540429  0.534597  0.538050  0.066402  0.187581
# 330  0.255713  0.865737  0.820300  0.017613  0.942820
# 331  0.869929  0.824764  0.437551  0.461891  0.036868
# 332  0.964515  0.395126  0.616877  0.681533  0.192099
# 333  0.463661  0.979576  0.000571  0.149838  0.309382
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.486645    0.499704    0.511862    0.526629    0.497851
# std      0.280312    0.279166    0.286930    0.280920    0.271923
# min      0.006308    0.001412    0.000571    0.007346    0.007489
# 25%      0.255200    0.289905    0.260880    0.290692    0.281502
# 50%      0.465140    0.486972    0.501214    0.557699    0.492574
# 75%      0.743263    0.713865    0.773206    0.774493    0.716475
# max      0.993137    0.997650    0.998872    0.996946    0.999887

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0] =
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D         E     0
# 0       240  0.862850  0.341169  0.201986  0.768530  28.0
# 1  0.144299  0.061437  0.126066  0.705308  0.810076   NaN
# 2  0.534083  0.332580  0.643512  0.552869  0.787630   NaN
# 3  0.978991  0.503777  0.756358  0.831947  0.367766   NaN
# 4  0.983951  0.579067  0.858073  0.202628  0.905762   NaN

# %%
newdf.loc[[1, 2], ['C', 'D']]
# Out:
#           C         D
# 1  0.126066  0.705308
# 2  0.643512  0.552869

# %%
newdf.head()
# Out:
#           A         B         C         D         E     0
# 0       240  0.862850  0.341169  0.201986  0.768530  28.0
# 1  0.144299  0.061437  0.126066  0.705308  0.810076   NaN
# 2  0.534083  0.332580  0.643512  0.552869  0.787630   NaN
# 3  0.978991  0.503777  0.756358  0.831947  0.367766   NaN
# 4  0.983951  0.579067  0.858073  0.202628  0.905762   NaN

# %%
newdf.loc[[1, 2], :]
# Out:
#           A         B         C         D         E   0
# 1  0.144299  0.061437  0.126066  0.705308  0.810076 NaN
# 2  0.534083  0.332580  0.643512  0.552869  0.787630 NaN

# %%
newdf.loc[:, ['C', 'D']]
# Out:
#             C         D
# 0    0.341169  0.201986
# 1    0.126066  0.705308
# 2    0.643512  0.552869
# 3    0.756358  0.831947
# 4    0.858073  0.202628
# ..        ...       ...
# 329  0.538050  0.066402
# 330  0.820300  0.017613
# 331  0.437551  0.461891
# 332  0.616877  0.681533
# 333  0.000571  0.149838
#
# [334 rows x 2 columns]

# %%
newdf.loc[(newdf['A'] < 0.3)]
# Out:
#             A         B         C         D         E   0
# 1    0.144299  0.061437  0.126066  0.705308  0.810076 NaN
# 10   0.238437  0.347068  0.873951  0.541666  0.844547 NaN
# 12    0.29101  0.879554  0.454821  0.660626  0.587528 NaN
# 13   0.291909  0.583543  0.188750  0.725415  0.627595 NaN
# 15   0.263814  0.217345  0.585751  0.714248  0.367713 NaN
# ..        ...       ...       ...       ...       ...  ..
# 314  0.261378  0.977188  0.523549  0.360645  0.534535 NaN
# 316  0.136161  0.486734  0.723201  0.108302  0.212870 NaN
# 322  0.053923  0.665711  0.369005  0.683551  0.834983 NaN
# 324  0.158335  0.436797  0.044407  0.597924  0.452764 NaN
# 330  0.255713  0.865737  0.820300  0.017613  0.942820 NaN
#
# [107 rows x 6 columns]

# %%
newdf.loc[(newdf['A'] < 0.3) & (newdf['C'] > 0.1)]
# Out:
#             A         B         C         D         E   0
# 1    0.144299  0.061437  0.126066  0.705308  0.810076 NaN
# 10   0.238437  0.347068  0.873951  0.541666  0.844547 NaN
# 12    0.29101  0.879554  0.454821  0.660626  0.587528 NaN
# 13   0.291909  0.583543  0.188750  0.725415  0.627595 NaN
# 15   0.263814  0.217345  0.585751  0.714248  0.367713 NaN
# ..        ...       ...       ...       ...       ...  ..
# 303  0.159451  0.438031  0.893507  0.583253  0.669346 NaN
# 314  0.261378  0.977188  0.523549  0.360645  0.534535 NaN
# 316  0.136161  0.486734  0.723201  0.108302  0.212870 NaN
# 322  0.053923  0.665711  0.369005  0.683551  0.834983 NaN
# 330  0.255713  0.865737  0.820300  0.017613  0.942820 NaN
#
# [96 rows x 6 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E     0
# 0       240  0.862850  0.341169  0.201986  0.768530  28.0
# 1  0.144299  0.061437  0.126066  0.705308  0.810076   NaN

# %%
newdf.iloc[0, 4]
# Out:
# 0.7685298071089675

# %%
newdf.iloc[[0,1], [1,2]]
# Out:
#           B         C
# 0  0.862850  0.341169
# 1  0.061437  0.126066

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E     0
# 0       240  0.862850  0.341169  0.201986  0.768530  28.0
# 1  0.144299  0.061437  0.126066  0.705308  0.810076   NaN
# 2  0.534083  0.332580  0.643512  0.552869  0.787630   NaN

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E   0
# 1    0.144299  0.061437  0.126066  0.705308  0.810076 NaN
# 2    0.534083  0.332580  0.643512  0.552869  0.787630 NaN
# 3    0.978991  0.503777  0.756358  0.831947  0.367766 NaN
# 4    0.983951  0.579067  0.858073  0.202628  0.905762 NaN
# 5    0.341136  0.801999  0.491115  0.483758  0.402775 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.540429  0.534597  0.538050  0.066402  0.187581 NaN
# 330  0.255713  0.865737  0.820300  0.017613  0.942820 NaN
# 331  0.869929  0.824764  0.437551  0.461891  0.036868 NaN
# 332  0.964515  0.395126  0.616877  0.681533  0.192099 NaN
# 333  0.463661  0.979576  0.000571  0.149838  0.309382 NaN
#
# [333 rows x 6 columns]

# %%
newdf.drop(['A', 'D'], axis = 1)
# Out:
#             B         C         E     0
# 0    0.862850  0.341169  0.768530  28.0
# 1    0.061437  0.126066  0.810076   NaN
# 2    0.332580  0.643512  0.787630   NaN
# 3    0.503777  0.756358  0.367766   NaN
# 4    0.579067  0.858073  0.905762   NaN
# ..        ...       ...       ...   ...
# 329  0.534597  0.538050  0.187581   NaN
# 330  0.865737  0.820300  0.942820   NaN
# 331  0.824764  0.437551  0.036868   NaN
# 332  0.395126  0.616877  0.192099   NaN
# 333  0.979576  0.000571  0.309382   NaN
#
# [334 rows x 4 columns]

# %%
newdf.drop([1, 5], axis = 0, inplace = True)

# %%
newdf
# Out:
#             B         C         E     0
# 0    0.862850  0.341169  0.768530  28.0
# 2    0.332580  0.643512  0.787630   NaN
# 3    0.503777  0.756358  0.367766   NaN
# 4    0.579067  0.858073  0.905762   NaN
# 6    0.015601  0.631198  0.999385   NaN
# ..        ...       ...       ...   ...
# 329  0.534597  0.538050  0.187581   NaN
# 330  0.865737  0.820300  0.942820   NaN
# 331  0.824764  0.437551  0.036868   NaN
# 332  0.395126  0.616877  0.192099   NaN
# 333  0.979576  0.000571  0.309382   NaN
#
# [332 rows x 4 columns]

# %%
newdf.reset_index(drop = True, inplace = True)

# %%
newdf.head(3)
# Out:
#           B         C         E     0
# 0  0.862850  0.341169  0.768530  28.0
# 1  0.332580  0.643512  0.787630   NaN
# 2  0.503777  0.756358  0.367766   NaN

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B'] = None

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']] = 56

# %%
newdf
# Out:
#       B         C         E     0
# 0    56  0.341169  0.768530  28.0
# 1    56  0.643512  0.787630   NaN
# 2    56  0.756358  0.367766   NaN
# 3    56  0.858073  0.905762   NaN
# 4    56  0.631198  0.999385   NaN
# ..   ..       ...       ...   ...
# 327  56  0.538050  0.187581   NaN
# 328  56  0.820300  0.942820   NaN
# 329  56  0.437551  0.036868   NaN
# 330  56  0.616877  0.192099   NaN
# 331  56  0.000571  0.309382   NaN
#
# [332 rows x 4 columns]

# %%
newdf.head()
# Out:
#     B         C         E     0
# 0  56  0.341169  0.768530  28.0
# 1  56  0.643512  0.787630   NaN
# 2  56  0.756358  0.367766   NaN
# 3  56  0.858073  0.905762   NaN
# 4  56  0.631198  0.999385   NaN

# %%
df = pd.DataFrame({"Name":['Alpha', 'Beta', 'Beta'],
                  "toy":[np.nan, 'Batmobile', 'Bullwhip'],
                  "born":[pd.NaT, pd.Timestamp("2001-04-24"), pd.NaT]})

# %%
df.head()
# Out:
#     Name        toy       born
# 0  Alpha        NaN        NaT
# 1   Beta  Batmobile 2001-04-24
# 2  Gamma   Bullwhip        NaT

# %%
df.dropna()
# Out:
#    Name        toy       born
# 1  Beta  Batmobile 2001-04-24

# %%
df.dropna(how = 'all', axis = 1)
# Out:
#     Name        toy       born
# 0  Alpha        NaN        NaT
# 1   Beta  Batmobile 2001-04-24
# 2  Gamma   Bullwhip        NaT

# %%
df.drop_duplicates(subset = ['Name'])
# Out:
#     Name        toy       born
# 0  Alpha        NaN        NaT
# 1   Beta  Batmobile 2001-04-24

# %%
df.drop_duplicates(subset = ['Name'], keep = False)
# Out:
#     Name  toy born
# 0  Alpha  NaN  NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 200.0+ bytes

# %%
df['toy'].value_counts(dropna = False)
# Out:
# NaN          1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df.isnull()
# Out:
#     Name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
dataf = pd.DataFrame({"col1":[24, 12, 64],
                     "col2":[6, 3, 98]})

# %%
dataf
# Out:
#    col1  col2
# 0    24     6
# 1    12     3
# 2    64    98

# %%
dataf.describe()
# Out:
#             col1       col2
# count   3.000000   3.000000
# mean   33.333333  35.666667
# std    27.227437  54.003086
# min    12.000000   3.000000
# 25%    18.000000   4.500000
# 50%    24.000000   6.000000
# 75%    44.000000  52.000000
# max    64.000000  98.000000

# %%
dataf.mean()
# Out:
# col1    33.333333
# col2    35.666667
# dtype: float64

# %%
dataf.corr()
# Out:
#           col1      col2
# col1  1.000000  0.981162
# col2  0.981162  1.000000

# %%
dataf.count()
# Out:
# col1    3
# col2    3
# dtype: int64

# %%
dataf.max()
# Out:
# col1    64
# col2    98
# dtype: int64

# %%
dataf.min()
# Out:
# col1    12
# col2     3
# dtype: int64

# %%
dataf.median()
# Out:
# col1    24.0
# col2     6.0
# dtype: float64

# %%
dataf.std()
# Out:
# col1    27.227437
# col2    54.003086
# dtype: float64

# %%
dataf
# Out:
#    col1  col2
# 0    24     6
# 1    12     3
# 2    64    98
